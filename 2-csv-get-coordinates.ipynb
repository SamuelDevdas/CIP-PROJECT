# %% [markdown]
# ### Load and Inspect "Countries-Coordinates" CSV format Data

# %%
# Read semi-colon separated file with geolocation data
import pandas as pd

df_geo = pd.read_csv("raw-countries-coordinates.csv", sep=";")

# print the shape of the Geo data
print(df_geo.shape)

# Show first 5 rows
df_geo.head()
# Out:
# (255, 96)
#                       Geo Point  \
# 0   53.5318804783, 28.033566395
# 1  51.1063634863, 10.3814938434
# 2   27.0302779758, 18.009605121
# 3  11.7501558755, 42.5664536523
# 4  24.1223270695, 44.5368636774
#
#                                            Geo Shape       featurecla  \
# 0  {"coordinates": [[[23.60623824100014, 51.51739...  Admin-0 country
# 1  {"coordinates": [[[[13.815724731000072, 48.766...  Admin-0 country
# 2  {"coordinates": [[[11.505111803000144, 33.1812...  Admin-0 country
# 3  {"coordinates": [[[43.240733269000074, 11.4878...  Admin-0 country
# 4  {"coordinates": [[[[50.80787194100008, 24.7466...  Admin-0 country
#
#    scalerank  LABELRANK    SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0          0          4       Belarus    BLR         0      2
# 1          0          2       Germany    DEU         0      2
# 2          0          3         Libya    LBY         0      2
# 3          0          5      Djibouti    DJI         0      2
# 4          0          2  Saudi Arabia    SAU         0      2
#
#                 TYPE  ...  NAME_JA  NAME_KO        NAME_NL           NAME_PL  \
# 0  Sovereign country  ...    ベラルーシ     벨라루스    Wit-Rusland          Białoruś
# 1  Sovereign country  ...      ドイツ       독일      Duitsland            Niemcy
# 2  Sovereign country  ...      リビア      리비아          Libië             Libia
# 3  Sovereign country  ...      ジブチ      지부티       Djibouti           Dżibuti
# 4  Sovereign country  ...  サウジアラビア  사우디아라비아  Saoedi-Arabië  Arabia Saudyjska
#
#           NAME_PT            NAME_RU       NAME_SV          NAME_TR  \
# 0    Bielorrússia         Белоруссия   Vitryssland      Beyaz Rusya
# 1        Alemanha           Германия      Tyskland          Almanya
# 2           Líbia              Ливия        Libyen            Libya
# 3        Djibouti            Джибути      Djibouti           Cibuti
# 4  Arábia Saudita  Саудовская Аравия  Saudiarabien  Suudi Arabistan
#
#        NAME_VI NAME_ZH
# 0      Belarus     白罗斯
# 1          Đức      德国
# 2        Libya     利比亚
# 3     Djibouti     吉布提
# 4  Ả Rập Saudi   沙特阿拉伯
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Rename columns to match the other dataframes
df_geo.rename(
    columns={
        "SOVEREIGNT": "Country",
        "Geo Point": "coordinates",
        "SOV_A3": "Country-code",
        "CONTINENT": "continent",
    },
    inplace=True,
)

# Show first 5 rows
df_geo.head()
# Out:
#                     coordinates  \
# 0   53.5318804783, 28.033566395
# 1  51.1063634863, 10.3814938434
# 2   27.0302779758, 18.009605121
# 3  11.7501558755, 42.5664536523
# 4  24.1223270695, 44.5368636774
#
#                                            Geo Shape       featurecla  \
# 0  {"coordinates": [[[23.60623824100014, 51.51739...  Admin-0 country
# 1  {"coordinates": [[[[13.815724731000072, 48.766...  Admin-0 country
# 2  {"coordinates": [[[11.505111803000144, 33.1812...  Admin-0 country
# 3  {"coordinates": [[[43.240733269000074, 11.4878...  Admin-0 country
# 4  {"coordinates": [[[[50.80787194100008, 24.7466...  Admin-0 country
#
#    scalerank  LABELRANK       Country Country-code  ADM0_DIF  LEVEL  \
# 0          0          4       Belarus          BLR         0      2
# 1          0          2       Germany          DEU         0      2
# 2          0          3         Libya          LBY         0      2
# 3          0          5      Djibouti          DJI         0      2
# 4          0          2  Saudi Arabia          SAU         0      2
#
#                 TYPE  ...  NAME_JA  NAME_KO        NAME_NL           NAME_PL  \
# 0  Sovereign country  ...    ベラルーシ     벨라루스    Wit-Rusland          Białoruś
# 1  Sovereign country  ...      ドイツ       독일      Duitsland            Niemcy
# 2  Sovereign country  ...      リビア      리비아          Libië             Libia
# 3  Sovereign country  ...      ジブチ      지부티       Djibouti           Dżibuti
# 4  Sovereign country  ...  サウジアラビア  사우디아라비아  Saoedi-Arabië  Arabia Saudyjska
#
#           NAME_PT            NAME_RU       NAME_SV          NAME_TR  \
# 0    Bielorrússia         Белоруссия   Vitryssland      Beyaz Rusya
# 1        Alemanha           Германия      Tyskland          Almanya
# 2           Líbia              Ливия        Libyen            Libya
# 3        Djibouti            Джибути      Djibouti           Cibuti
# 4  Arábia Saudita  Саудовская Аравия  Saudiarabien  Suudi Arabistan
#
#        NAME_VI NAME_ZH
# 0      Belarus     白罗斯
# 1          Đức      德国
# 2        Libya     利比亚
# 3     Djibouti     吉布提
# 4  Ả Rập Saudi   沙特阿拉伯
#
# [5 rows x 96 columns]

# %%
# Drop all columns except Country, coordinates and continent

# Create a list of columns
columns_list = ["Country", "coordinates", "continent"]

# Drop all columns except the ones in the list
df_geo = df_geo[columns_list]

# Show first 5 rows
df_geo.head()
# Out:
#         Country                   coordinates continent
# 0       Belarus   53.5318804783, 28.033566395    Europe
# 1       Germany  51.1063634863, 10.3814938434    Europe
# 2         Libya   27.0302779758, 18.009605121    Africa
# 3      Djibouti  11.7501558755, 42.5664536523    Africa
# 4  Saudi Arabia  24.1223270695, 44.5368636774      Asia

# %%
# Filter only European countries
df_geo_eur = df_geo[df_geo["continent"] == "Europe"]

# %%
# checking for duplicates in column Country
df_geo_eur[df_geo_eur.duplicated(subset=["Country"])]
# Out:
#             Country                    coordinates continent
# 51   United Kingdom  49.4843729229, -2.53048002329    Europe
# 147         Denmark   55.9653774566, 10.0513897028    Europe
# 157         Finland   64.4953589823, 26.2707950346    Europe
# 164  United Kingdom  36.1294636704, -5.34670032371    Europe
# 214  United Kingdom  54.2291019004, -4.53369508308    Europe
# 216  United Kingdom  54.1470481882, -2.88695151937    Europe

# %%
# Drop duplicates in column Country
df_geo_eur.drop_duplicates(subset=["Country"], inplace=True)

# checking for duplicates in column Country
df_geo_eur[df_geo_eur.duplicated(subset=["Country"])]
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_7488\3299542697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo_eur.drop_duplicates(subset=["Country"], inplace=True)
# Empty DataFrame
# Columns: [Country, coordinates, continent]
# Index: []

# %%
# Save dataframe to csv file
df_geo_eur.to_csv("clean-coordinates-data.csv", index=False)

# %%
df_geo_eur["Country"].__len__()
# Out:
# 45
